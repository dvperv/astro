# %% [markdown]
# import os
# import numpy as np
# import struct
#
# cwd = r"C:\Users\dvperv\Google Диск\Пущино\cubes-prao"
# os.chdir(cwd)
#
# astro_id = []
# astro_data = []
# astro_label = []
#
# i = 0
#
# for file in os.listdir(cwd):
#     i += 1
#     if i > 10:
#         break
#
#     nnId, rest = file.split("_")
#     nnray, label = rest.split(".")
#     astro_id.append((int(nnId), int(nnray)))
#
#     cube = []
#
#     with open(file, mode='rb') as file: # b is important -> binary
#         fileContent = file.read()
#         for data in struct.iter_unpack("f", fileContent):
#             cube.append(data[0])
#     astro_data.append(cube)
#     astro_label.append(int(label) - 101)
#
# npAstroD = np.array(astro_data)
# npAstroL = np.array(astro_label)
#
# os.chdir('..')
# compressedNpDataFile = r'savedNpAstro1.npz'
#
# np.savez_compressed(compressedNpDataFile, D=npAstroD, L=npAstroL)
#
# loaded = np.load(compressedNpDataFile)
#
# print(loaded['D'])
# print(loaded['L'])
#
# loaded.close()

# %%
import os
import numpy as np
import struct
import tensorflow as tf

cwd = r"C:\Users\dvperv\Google Диск\Пущино"
os.chdir(cwd)
compressedNpDataFile = r'savedNpAstro.npz'

with np.load(compressedNpDataFile) as data:
    features = data["D"]
    labels = data["L"]
    data.close()

print (features)
    
# dataset = tf.data.Dataset.from_tensor_slices((features, labels))

# print(dataset)

# tensor = dataset.make_one_shot_iterator().get_next()
# with tf.Session() as session:
#     print(session.run(tensor))
#     print(session.run(tensor))
#     print(session.run(tensor))
# Out:
# [list([811.2969970703125, 818.3400268554688, 818.927001953125, 817.5490112304688, 819.2119750976562, 820.3809814453125, 823.864990234375, 821.6699829101562, 821.5330200195312, 814.6199951171875, 808.2570190429688, 821.1500244140625, 829.1170043945312, 819.9420166015625, 823.1270141601562, 811.4299926757812, 814.3989868164062, 813.8779907226562, 817.8369750976562, 826.4979858398438, 817.823974609375, 814.3759765625, 813.4660034179688, 829.4739990234375, 823.4739990234375, 820.2890014648438, 816.8060302734375, 825.7680053710938, 825.2150268554688, 847.2039794921875, 819.4420166015625, 821.7919921875, 814.89501953125, 816.8209838867188, 803.4910278320312, 817.6929931640625, 822.4340209960938, 815.8729858398438, 817.2379760742188, 816.9030151367188, 815.7100219726562, 821.2150268554688, 816.719970703125, 818.1400146484375, 816.5969848632812, 816.531005859375, 820.7360229492188, 822.7689819335938, 814.5349731445312, 814.7579956054688, 824.5919799804688, 823.2630004882812, 823.213989257812
# ...

# %%
# https://www.tensorflow.org/tutorials/keras/basic_classification

from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(1800, activation=tf.nn.relu),
    keras.layers.Dense(51, activation=tf.nn.softmax)
])

model.compile(optimizer=tf.train.AdamOptimizer(), 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5)

test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
