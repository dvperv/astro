# %%
import os
import numpy as np
import struct
# from sklearn import preprocessing

cwd = r"C:\astrodata\temp"
os.chdir(cwd)

astro_id = [] # np.ndarray(shape=(2), dtype=int, order='C')
astro_data = [] # np.ndarray(shape=(300, 6), dtype=float, order='C')
astro_label = [] # np.ndarray(shape=(1), dtype=int, order='C')

count = 0

for file in os.listdir(cwd):
    count += 1
#     if count >= 10:
#         break
    
    nnId, rest = file.split("_")
    nnray, label = rest.split(".")
    
    astro_id.append([int(nnId), int(nnray)])
    astro_label.append(int(label) - 101)
    
    with open(file, mode='rb') as file: # b is important -> binary
        fileContent = file.read()
        
        for data in struct.iter_unpack("f", fileContent):
            astro_data.append(data[0])
            
# min_max_scaler = preprocessing.MinMaxScaler()
# astro_data = min_max_scaler.fit_transform(astro_data)
npAstroD = np.resize(np.array(astro_data), (count, 6, 300))
npAstroL = np.array(astro_label)
# npAstroD

print(count)
os.chdir('..')
compressedNpDataFile = r'savedNpAstro_2.0.npz'

np.savez_compressed(compressedNpDataFile, D=npAstroD, L=npAstroL)

loaded = np.load(compressedNpDataFile)

print(loaded['D'])
print(loaded['L'])
print(loaded['L'].size)

loaded.close()
# Out:
# 83096
# [[[811.29699707 818.34002686 818.92700195 ... 825.42901611 825.7119751
#    821.99499512]
#   [836.20098877 841.79998779 837.19799805 ... 845.4119873  843.36499023
#    841.10797119]
#   [840.57299805 843.16699219 827.82397461 ... 841.51300049 853.51202393
#    849.42199707]
#   [834.14697266 835.74700928 821.85198975 ... 831.34899902 839.88000488
#    835.98498535]
#   [788.55999756 791.72399902 785.35699463 ... 791.51397705 788.82501221
#    825.50598145]
#   [745.83197021 736.01501465 741.03497314 ... 751.39501953 763.23498535
#    777.56298828]]
#
#  [[824.74200439 813.76202393 818.65698242 ... 819.30102539 817.63702393
#    828.76898193]
#   [841.02801514 838.24499512 837.09997559 ... 843.58898926 839.46600342
#    846.52301025]
#   [840.8380127  839.26000977 843.52001953 ... 844.82397461 841.7800293
#    840.73498535]
#   [837.54602051 831.88397217 826.98498535 ... 846.14001465 835.76800537
#    828.86602783]
#   [782.82202148 783.934021   782.11102295 ... 798.49700928 792.8449707
#    796.90802002]
#   [747.21899414 747.24200439 737.36499023 ... 750.70501709 741.44396973
#    747.83001709]]
#
#  [[819.68200684 847.34698486 834.96801758 ... 829.53198242 817.69299316
#    823.04199219]
#   [845.84899902 876.71002197 838.6630249  ... 845.76202393 838.93103027
#    840.57501221]
#   [875.74700928 844.7789917  834.14099121 ... 847.83898926 845.47998047
#    856.95501709]
#   [856.54797363 838.74499512 838.31097412 ... 835.15997314 837.72998047
#    840.04901123]
#   [797.00500488 788.38500977 785.47900391 ... 797.30499268 794.71398926
#    796.83599854]
#   [740.04797363 743.51800537 748.66400146 ... 747.98101807 748.76098633
#    749.13201904]]
#
#  ...
#
#  [[440.45001221 445.5920105  436.47299194 ... 429.26098633 424.9750061
#    415.81100464]
#   [423.8710022  423.42498779 420.46499634 ... 407.4710083  402.95700073
#    404.20001221]
#   [399.52700806 397.2749939  405.38500977 ... 391.34698486 394.6289978
#    385.98901367]
#   [385.57299805 389.85998535 385.9039917  ... 789.11999512 801.17602539
#    794.29699707]
#   [795.00500488 815.91497803 810.77697754 ... 819.48498535 824.26800537
#    810.84899902]
#   [811.25897217 829.47900391 811.7800293  ... 821.10302734 822.63897705
#    826.53100586]]
#
#  [[832.7199707  815.059021   832.09802246 ... 819.7199707  809.69500732
#    821.44500732]
#   [825.24597168 819.059021   812.06500244 ... 776.54302979 776.51702881
#    784.02001953]
#   [761.8460083  766.94000244 775.02099609 ... 727.94799805 733.35601807
#    724.27398682]
#   [730.68798828 713.25299072 723.40997314 ... 797.21600342 800.68597412
#    802.43103027]
#   [816.61499023 802.71502686 804.96899414 ... 824.85302734 822.7800293
#    836.63897705]
#   [819.86798096 815.3170166  813.31298828 ... 836.49700928 849.78601074
#    831.30700684]]
#
#  [[815.24200439 819.94500732 829.50701904 ... 821.4050293  837.96801758
#    818.81500244]
#   [815.03601074 818.08398438 809.33599854 ... 797.29602051 767.75500488
#    771.80401611]
#   [772.64599609 778.75897217 781.36999512 ... 725.89300537 731.97399902
#    726.15899658]
#   [731.48797607 736.52001953 727.2789917  ... 810.59802246 811.41900635
#    807.73602295]
#   [803.12597656 832.         842.20202637 ... 824.51702881 823.40802002
#    821.86999512]
#   [825.9420166  867.63299561 827.07202148 ... 824.47900391 831.22900391
#    829.12298584]]]
# [50 50 50 ...  0 10 10]
# 83096
